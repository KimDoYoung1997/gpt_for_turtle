# %%
from openai import OpenAI
client = OpenAI()

# %%
response = client.responses.create(
    model="gpt-4.1",
    input=[
        {"role": "user", "content": "what teams are playing in this image?"},
        {
            "role": "user",
            "content": [
                {
                    "type": "input_image",
                    "image_url": "https://upload.wikimedia.org/wikipedia/commons/3/3b/LeBron_James_Layup_%28Cleveland_vs_Brooklyn_2018%29.jpg"
                }
            ]
        }
    ]
)
print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 4
#       1 from openai import OpenAI
#       2 client = OpenAI()
# ----> 4 response = client.responses.create(
#       5     model="gpt-4.1",
#       6     input=[
#       7         {"role": "user", "content": "what teams are playing in this image?"},
#       8         {
#       9             "role": "user",
#      10             "content": [
#      11                 {
#      12                     "type": "input_image",
#      13                     "image_url": "https://upload.wikimedia.org/wikipedia/commons/3/3b/LeBron_James_Layup_%28Cleveland_vs_Brooklyn_2018%29.jpg"
#      14                 }
#      15             ]
#      16         }
#      17     ]
#      18 )
#      20 print(response.output_text)
#
# File ~/.local/lib/python3.10/site-packages/openai/resources/responses/responses.py:735, in Responses.create(self, background, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, reasoning, service_tier, store, stream, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     702 def create(
#     703     self,
#     704     *,
#    (...)
#     733     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     734 ) -> Response | Stream[ResponseStreamEvent]:
# --> 735     return self._post(
#     736         "/responses",
#     737         body=maybe_transform(
#     738             {
#     739                 "background": background,
#     740                 "include": include,
#     741                 "input": input,
#     742                 "instructions": instructions,
#     743                 "max_output_tokens": max_output_tokens,
#     744                 "max_tool_calls": max_tool_calls,
#     745                 "metadata": metadata,
#     746                 "model": model,
#     747                 "parallel_tool_calls": parallel_tool_calls,
#     748                 "previous_response_id": previous_response_id,
#     749                 "prompt": prompt,
#     750                 "reasoning": reasoning,
#     751                 "service_tier": service_tier,
#     752                 "store": store,
#     753                 "stream": stream,
#     754                 "temperature": temperature,
#     755                 "text": text,
#     756                 "tool_choice": tool_choice,
#     757                 "tools": tools,
#     758                 "top_logprobs": top_logprobs,
#     759                 "top_p": top_p,
#     760                 "truncation": truncation,
#     761                 "user": user,
#     762             },
#     763             response_create_params.ResponseCreateParamsStreaming
#     764             if stream
#     765             else response_create_params.ResponseCreateParamsNonStreaming,
#     766         ),
#     767         options=make_request_options(
#     768             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     769         ),
#     770         cast_to=Response,
#     771         stream=stream or False,
#     772         stream_cls=Stream[ResponseStreamEvent],
#     773     )
#
# File ~/.local/lib/python3.10/site-packages/openai/_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)
#    1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/lib/python3.10/site-packages/openai/_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': 'Failed to download file from https://upload.wikimedia.org/wikipedia/commons/3/3b/LeBron_James_Layup_%28Cleveland_vs_Brooklyn_2018%29.jpg. File urls cannot be larger than 10MB.', 'type': 'invalid_request_error', 'param': 'url', 'code': 'file_above_max_size'}}

# %%
from openai import OpenAI
client = OpenAI()

stream = client.responses.create(
    model="gpt-4.1",
    input=[
        {
            "role": "user",
            "content": "Say 'double bubble bath' ten times fast.",
        },
    ],
    stream=True,
)

for event in stream:
    print(event)
# Out:
# ResponseCreatedEvent(response=Response(id='resp_687f244e4378819b81e2abd63d33d4b70d027a3b762dba70', created_at=1753162830.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-2025-04-14', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), service_tier='auto', status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text')), top_logprobs=0, truncation='disabled', usage=None, user=None, prompt_cache_key=None, safety_identifier=None, store=True), sequence_number=0, type='response.created')
# ResponseInProgressEvent(response=Response(id='resp_687f244e4378819b81e2abd63d33d4b70d027a3b762dba70', created_at=1753162830.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-2025-04-14', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), service_tier='auto', status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text')), top_logprobs=0, truncation='disabled', usage=None, user=None, prompt_cache_key=None, safety_identifier=None, store=True), sequence_number=1, type='response.in_progress')
# ResponseOutputItemAddedEvent(item=ResponseOutputMessage(id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', content=[], role='assistant', status='in_progress', type='message'), output_index=0, sequence_number=2, type='response.output_item.added')
# ResponseContentPartAddedEvent(content_index=0, item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, part=ResponseOutputText(annotations=[], text='', type='output_text', logprobs=[]), sequence_number=3, type='response.content_part.added')
# ResponseTextDeltaEvent(content_index=0, delta='Alright', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=4, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=5, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' here', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=6, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' goes', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=7, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=':\n\n', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=8, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta='Double', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=9, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=10, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=11, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=12, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=13, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=14, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=15, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=16, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=17, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=18, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=19, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=20, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=21, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=22, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=23, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=24, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=25, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=26, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=27, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=28, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=29, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=30, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=31, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=32, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=33, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=34, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=35, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=36, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=37, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=38, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=39, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=40, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=41, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=42, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=43, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=44, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=45, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=46, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=47, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta='!\n\n', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=48, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta='Try', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=49, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' saying', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=50, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' it', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=51, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' out', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=52, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' loud', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=53, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' yourself', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=54, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta='—', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=55, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta="it's", item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=56, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' quite', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=57, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=58, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' tongue', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=59, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' tw', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=60, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta='ister', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=61, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta='!', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=62, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' Want', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=63, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' to', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=64, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' try', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=65, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' another', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=66, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta=' one', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=67, type='response.output_text.delta', logprobs=[])
# ResponseTextDeltaEvent(content_index=0, delta='?', item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=68, type='response.output_text.delta', logprobs=[])
# ResponseTextDoneEvent(content_index=0, item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, sequence_number=69, text="Alright, here goes:\n\nDouble bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath!\n\nTry saying it out loud yourself—it's quite a tongue twister! Want to try another one?", type='response.output_text.done', logprobs=[])
# ResponseContentPartDoneEvent(content_index=0, item_id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', output_index=0, part=ResponseOutputText(annotations=[], text="Alright, here goes:\n\nDouble bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath!\n\nTry saying it out loud yourself—it's quite a tongue twister! Want to try another one?", type='output_text', logprobs=[]), sequence_number=70, type='response.content_part.done')
# ResponseOutputItemDoneEvent(item=ResponseOutputMessage(id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', content=[ResponseOutputText(annotations=[], text="Alright, here goes:\n\nDouble bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath!\n\nTry saying it out loud yourself—it's quite a tongue twister! Want to try another one?", type='output_text', logprobs=[])], role='assistant', status='completed', type='message'), output_index=0, sequence_number=71, type='response.output_item.done')
# ResponseCompletedEvent(response=Response(id='resp_687f244e4378819b81e2abd63d33d4b70d027a3b762dba70', created_at=1753162830.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-2025-04-14', object='response', output=[ResponseOutputMessage(id='msg_687f244efd58819ba5f9a79864a8e8460d027a3b762dba70', content=[ResponseOutputText(annotations=[], text="Alright, here goes:\n\nDouble bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath, double bubble bath!\n\nTry saying it out loud yourself—it's quite a tongue twister! Want to try another one?", type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text')), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=17, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=66, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=83), user=None, prompt_cache_key=None, safety_identifier=None, store=True), sequence_number=72, type='response.completed')

# %%
from agents import Agent, Runner
import asyncio

spanish_agent = Agent(
    name="Spanish agent",
    instructions="You only speak Spanish.",
)

english_agent = Agent(
    name="English agent",
    instructions="You only speak English",
)

triage_agent = Agent(
    name="Triage agent",
    instructions="Handoff to the appropriate agent based on the language of the request.",
    handoffs=[spanish_agent, english_agent],
)


async def main():
    result = await Runner.run(triage_agent, input="Hola, ¿cómo estás?")
    print(result.final_output)


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from agents import Agent, Runner
#       2 import asyncio
#       4 spanish_agent = Agent(
#       5     name="Spanish agent",
#       6     instructions="You only speak Spanish.",
#       7 )
#
# ModuleNotFoundError: No module named 'agents'
